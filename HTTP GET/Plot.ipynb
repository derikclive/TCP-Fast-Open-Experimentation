# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np

# %%
values = pd.read_csv('results.csv')

# %%
values
# Out:
#         Website            tcp  Time for transfer  Delay  Bandwidth
# 0      flipkart  tcp fast_open               0.12     20          1
# 1      flipkart        vanilla               0.20     20          1
# 2      flipkart  tcp fast_open               0.12     20          2
# 3      flipkart        vanilla               0.20     20          2
# 4      flipkart  tcp fast_open               0.12     20          5
# 5      flipkart        vanilla               0.20     20          5
# 6      flipkart  tcp fast_open               0.12     20         10
# 7      flipkart        vanilla               0.20     20         10
# 8      flipkart  tcp fast_open               0.60    100          1
# 9      flipkart        vanilla               1.00    100          1
# 10     flipkart  tcp fast_open               0.60    100          2
# 11     flipkart        vanilla               1.00    100          2
# 12     flipkart  tcp fast_open               0.60    100          5
# 13     flipkart        vanilla               1.00    100          5
# 14     flipkart  tcp fast_open               0.60    100         10
# 15     flipkart        vanilla               1.00    100         10
# 16     flipkart  tcp fast_open               1.20    200          1
# 17     flipkart        vanilla               2.00    200          1
# 18     flipkart  tcp fast_open               1.20    200          2
# 19     flipkart        vanilla               2.00    200          2
# 20     flipkart  tcp fast_open               1.20    200          5
# 21     flipkart        vanilla               2.00    200          5
# 22     flipkart  tcp fast_open               1.20    200         10
# 23     flipkart        vanilla               2.00    200         10
# 24   amazon_in,  tcp fast_open               0.12     20          1
# 25   amazon_in,        vanilla               0.20     20          1
# 26   amazon_in,  tcp fast_open               0.12     20          2
# 27   amazon_in,        vanilla               0.20     20          2
# 28   amazon_in,  tcp fast_open               0.12     20          5
# 29   amazon_in,        vanilla               0.20     20          5
# ..          ...            ...                ...    ...        ...
# 90      jabong,  tcp fast_open               1.20    200          2
# 91      jabong,        vanilla               2.00    200          2
# 92      jabong,  tcp fast_open               1.20    200          5
# 93      jabong,        vanilla               2.00    200          5
# 94      jabong,  tcp fast_open               1.21    200         10
# 95      jabong,        vanilla               2.00    200         10
# 96     wiki_tcp  tcp fast_open               5.59     20          1
# 97     wiki_tcp        vanilla               5.73     20          1
# 98     wiki_tcp  tcp fast_open               2.88     20          2
# 99     wiki_tcp        vanilla               3.04     20          2
# 100    wiki_tcp  tcp fast_open               1.27     20          5
# 101    wiki_tcp        vanilla               1.47     20          5
# 102    wiki_tcp  tcp fast_open               0.78     20         10
# 103    wiki_tcp        vanilla               1.00     20         10
# 104    wiki_tcp  tcp fast_open               6.34    100          1
# 105    wiki_tcp        vanilla               7.31    100          1
# 106    wiki_tcp  tcp fast_open               3.85    100          2
# 107    wiki_tcp        vanilla               4.90    100          2
# 108    wiki_tcp  tcp fast_open               2.79    100          5
# 109    wiki_tcp        vanilla               3.90    100          5
# 110    wiki_tcp  tcp fast_open               2.70    100         10
# 111    wiki_tcp        vanilla               3.85    100         10
# 112    wiki_tcp  tcp fast_open               7.70    200          1
# 113    wiki_tcp        vanilla               9.75    200          1
# 114    wiki_tcp  tcp fast_open               5.76    200          2
# 115    wiki_tcp        vanilla               8.03    200          2
# 116    wiki_tcp  tcp fast_open               5.39    200          5
# 117    wiki_tcp        vanilla               7.69    200          5
# 118    wiki_tcp  tcp fast_open               5.30    200         10
# 119    wiki_tcp        vanilla               7.65    200         10
#
# [120 rows x 5 columns]

# %%
websites = values.Website.unique()
delays = np.array(values.Delay.unique())
delays.sort()
bandwidth = np.array(values.Bandwidth.unique())
bandwidth.sort()
fig, ax = plt.subplots(ncols = bandwidth.shape[0],nrows = websites.shape[0], figsize=(30, 15))
x = 0
y = 0
width = 0.35
#fig.subplots_adjust(hspace=0.5)
for website in websites:
    for bw in bandwidth:
        ip = values[values.Website == website]
        ip1 = ip[ip.tcp =='vanilla']
        ip1 = ip1[ip1.Bandwidth == bw]
        ip2 = ip[ip.tcp =='tcp fast_open']
        y_pos = np.arange(ip1.shape[0])
        ip2 = ip2[ip2.Bandwidth == bw]

        rects1 = ax[x][y].bar(y_pos, ip1['Time for transfer'],width, color='g')

        rects2 = ax[x][y].bar(y_pos + width, ip2['Time for transfer'],width, color='b')

        ax[x][y].set_ylabel("Time for transfer")
        ax[x][y].set_xlabel("Delay")
        ax[x][y].set_title(website + " Bandwidth: " + str(bw))
        ax[x][y].set_xticks(y_pos)
        ax[x][y].set_xticklabels(delays)
        ax[x][y].legend((rects1[0], rects2[0]), ('TCP Vanilla', 'TCP Fast Open'))
        y = y + 1
    x = x + 1
    y = 0
plt.tight_layout()
plt.show()
fig.savefig("plots.png")
